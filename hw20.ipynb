# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns
# %matplotlib inline

# ignore Deprecation Warning
import warnings
warnings.filterwarnings("ignore", category=DeprecationWarning) 


from sklearn.ensemble import RandomForestRegressor
import keras 
from keras.models import Sequential 
from keras.layers import Dense


df_train = pd.read_csv('/content/train.csv')
df_test = pd.read_csv('/content/test.csv')
df = df_train.append(df_test , ignore_index = True)
# Out:
# <ipython-input-2-0a4c058d8509>:20: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   df = df_train.append(df_test , ignore_index = True)

# %%
df_train.shape
# Out:
# (891, 12)

# %%
df_test.shape
# Out:
# (418, 11)

# %%
df_train.columns.values
# Out:
# array(['PassengerId', 'Survived', 'Pclass', 'Name', 'Sex', 'Age', 'SibSp',
#        'Parch', 'Ticket', 'Fare', 'Cabin', 'Embarked'], dtype=object)

# %%
df['Pclass'].isnull().sum(axis=0)
# Out:
# 0

# %%
df[['Pclass', 'Survived']].groupby(['Pclass'], as_index=False).mean()
# Out:
#    Pclass  Survived
# 0       1  0.629630
# 1       2  0.472826
# 2       3  0.242363

# %%
df.Name.head(10)
# Out:
# 0                              Braund, Mr. Owen Harris
# 1    Cumings, Mrs. John Bradley (Florence Briggs Th...
# 2                               Heikkinen, Miss. Laina
# 3         Futrelle, Mrs. Jacques Heath (Lily May Peel)
# 4                             Allen, Mr. William Henry
# 5                                     Moran, Mr. James
# 6                              McCarthy, Mr. Timothy J
# 7                       Palsson, Master. Gosta Leonard
# 8    Johnson, Mrs. Oscar W (Elisabeth Vilhelmina Berg)
# 9                  Nasser, Mrs. Nicholas (Adele Achem)
# Name: Name, dtype: object

# %%
df['Title'] = df.Name.map( lambda x: x.split(',')[1].split( '.' )[0].strip())

# %%
df['Title'].value_counts()
# Out:
# Mr              757
# Miss            260
# Mrs             197
# Master           61
# Rev               8
# Dr                8
# Col               4
# Mlle              2
# Major             2
# Ms                2
# Lady              1
# Sir               1
# Mme               1
# Don               1
# Capt              1
# the Countess      1
# Jonkheer          1
# Dona              1
# Name: Title, dtype: int64

# %%
df['Title'] = df['Title'].replace('Mlle', 'Miss')
df['Title'] = df['Title'].replace(['Mme','Lady','Ms'], 'Mrs')
df.Title.loc[ (df.Title !=  'Master') & (df.Title !=  'Mr') & (df.Title !=  'Miss') 
             & (df.Title !=  'Mrs')] = 'Others'

# inspect the correlation between Title and Survived
df[['Title', 'Survived']].groupby(['Title'], as_index=False).mean()
# Out:
# <ipython-input-12-ca5b01c1fdba>:3: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df.Title.loc[ (df.Title !=  'Master') & (df.Title !=  'Mr') & (df.Title !=  'Miss')
#     Title  Survived
# 0  Master  0.575000
# 1    Miss  0.701087
# 2      Mr  0.156673
# 3     Mrs  0.796875
# 4  Others  0.318182

# %%
df['Title'].value_counts()
# Out:
# Mr        757
# Miss      262
# Mrs       201
# Master     61
# Others     28
# Name: Title, dtype: int64

# %%
df = pd.concat([df, pd.get_dummies(df['Title'])], axis=1).drop(labels=['Name'], axis=1)

# %%
df.Sex.isnull().sum(axis=0)
# Out:
# 0

# %%
df[['Sex', 'Survived']].groupby(['Sex'], as_index=False).mean()
# Out:
#       Sex  Survived
# 0  female  0.742038
# 1    male  0.188908

# %%
df.Sex = df.Sex.map({'male':0, 'female':1})

# %%
df.Age.isnull().sum(axis=0)
# Out:
# 263

# %%
df.SibSp.isnull().sum(axis=0), df.Parch.isnull().sum(axis=0)
# Out:
# (0, 0)

# %%
df['Family'] = df['SibSp'] + df['Parch'] + 1

df[['Family', 'Survived']].groupby(['Family'], as_index=False).mean()
# Out:
#    Family  Survived
# 0       1  0.303538
# 1       2  0.552795
# 2       3  0.578431
# 3       4  0.724138
# 4       5  0.200000
# 5       6  0.136364
# 6       7  0.333333
# 7       8  0.000000
# 8      11  0.000000

# %%
df['Family'].value_counts()
# Out:
# 1     790
# 2     235
# 3     159
# 4      43
# 6      25
# 5      22
# 7      16
# 11     11
# 8       8
# Name: Family, dtype: int64

# %%
df.Family = df.Family.map(lambda x: 0 if x > 4 else x)
df[['Family', 'Survived']].groupby(['Family'], as_index=False).mean()
# Out:
#    Family  Survived
# 0       0  0.161290
# 1       1  0.303538
# 2       2  0.552795
# 3       3  0.578431
# 4       4  0.724138

# %%
df['Family'].value_counts()
# Out:
# 1    790
# 2    235
# 3    159
# 0     82
# 4     43
# Name: Family, dtype: int64

# %%
df.Ticket.isnull().sum(axis=0)
# Out:
# 0

# %%
df.Ticket.head(20)

# %%
df.Ticket = df.Ticket.map(lambda x: x[0])

# inspect the correlation between Ticket and Survived
df[['Ticket', 'Survived']].groupby(['Ticket'], as_index=False).mean()
# Out:
#    Ticket  Survived
# 0       1  0.630137
# 1       2  0.464481
# 2       3  0.239203
# 3       4  0.200000
# 4       5  0.000000
# 5       6  0.166667
# 6       7  0.111111
# 7       8  0.000000
# 8       9  1.000000
# 9       A  0.068966
# 10      C  0.340426
# 11      F  0.571429
# 12      L  0.250000
# 13      P  0.646154
# 14      S  0.323077
# 15      W  0.153846

# %%
# inspect the amount of people for each type of tickets
df['Ticket'].value_counts()
# Out:
# 3    429
# 2    278
# 1    210
# P     98
# S     98
# C     77
# A     42
# W     19
# 7     13
# F     13
# 4     11
# 6      9
# L      5
# 5      3
# 9      2
# 8      2
# Name: Ticket, dtype: int64

# %%
df[['Ticket', 'Fare']].groupby(['Ticket'], as_index=False).mean()
# Out:
#    Ticket        Fare
# 0       1   65.771211
# 1       2   20.235194
# 2       3   15.380682
# 3       4   16.764036
# 4       5   19.262500
# 5       6   19.153711
# 6       7    9.197438
# 7       8    8.397900
# 8       9    7.750000
# 9       A   10.189681
# 10      C   28.152273
# 11      F   24.677246
# 12      L    1.515000
# 13      P  119.698253
# 14      S   17.542900
# 15      W   31.056579

# %%
df[['Ticket', 'Pclass']].groupby(['Ticket'], as_index=False).mean()
# Out:
#    Ticket    Pclass
# 0       1  1.147619
# 1       2  2.309353
# 2       3  2.904429
# 3       4  3.000000
# 4       5  2.333333
# 5       6  2.111111
# 6       7  3.000000
# 7       8  3.000000
# 8       9  3.000000
# 9       A  3.000000
# 10      C  2.558442
# 11      F  1.846154
# 12      L  3.000000
# 13      P  1.102041
# 14      S  2.561224
# 15      W  2.315789

# %%
df.Fare.isnull().sum(axis=0)
# Out:
# 1

# %%
df.Ticket[df.Fare.isnull()]
# Out:
# 1043    3
# Name: Ticket, dtype: object

# %%
df.Pclass[df.Fare.isnull()]
# Out:
# 1043    3
# Name: Pclass, dtype: int64

# %%
df.Cabin[df.Fare.isnull()]
# Out:
# 1043    NaN
# Name: Cabin, dtype: object

# %%
df.Embarked[df.Fare.isnull()]
# Out:
# 1043    S
# Name: Embarked, dtype: object

# %%
df.Embarked[df.Fare.isnull()]
# Out:
# 1043    S
# Name: Embarked, dtype: object

# %%
sns.boxplot(x='Pclass', y='Fare', data=df)
plt.ylim(0, 300) 
plt.show()

# %%
df[['Pclass', 'Fare']].groupby(['Pclass']).mean()
# Out:
#              Fare
# Pclass
# 1       87.508992
# 2       21.179196
# 3       13.302889

# %%
df[['Pclass', 'Fare']].groupby(['Pclass']).std() / df[['Pclass', 'Fare']].groupby(['Pclass']).mean()
# Out:
#             Fare
# Pclass
# 1       0.919302
# 2       0.642476
# 3       0.864050

# %%
sns.boxplot(x='Ticket', y='Fare', data=df)
plt.ylim(0, 300) 
plt.show()

# %%
df[['Ticket', 'Fare']].groupby(['Ticket']).mean()
# Out:
#               Fare
# Ticket
# 1        65.771211
# 2        20.235194
# 3        15.380682
# 4        16.764036
# 5        19.262500
# 6        19.153711
# 7         9.197438
# 8         8.397900
# 9         7.750000
# A        10.189681
# C        28.152273
# F        24.677246
# L         1.515000
# P       119.698253
# S        17.542900
# W        31.056579

# %%
df[['Ticket', 'Fare']].groupby(['Ticket']).std() /  df[['Ticket', 'Fare']].groupby(['Ticket']).mean()
# Out:
#             Fare
# Ticket
# 1       0.817411
# 2       1.284139
# 3       1.351244
# 4       0.497578
# 5       0.284367
# 6       0.735873
# 7       0.080078
# 8       0.005961
# 9       0.000000
# A       0.466846
# C       0.736299
# F       0.556023
# L       2.236068
# P       0.944596
# S       1.024639
# W       0.676999

# %%
sns.boxplot(x='Embarked',y='Fare',data=df)
plt.ylim(0, 300) 
plt.show()

# %%
df[['Embarked', 'Fare']].groupby(['Embarked']).mean()
# Out:
#                Fare
# Embarked
# C         62.336267
# Q         12.409012
# S         27.418824

# %%
df[['Embarked', 'Fare']].groupby(['Embarked']).std() /  df[['Embarked', 'Fare']].groupby(['Embarked']).mean()
# Out:
#               Fare
# Embarked
# C         1.350514
# Q         1.097278
# S         1.352954

# %%
guess_Fare = df.Fare.loc[ (df.Ticket == '3') & (df.Pclass == 3) & (df.Embarked == 'S')].median()
df.Fare.fillna(guess_Fare , inplace=True)

# inspect the mean Fare values for people who died and survived
df[['Fare', 'Survived']].groupby(['Survived'],as_index=False).mean()
# Out:
#    Survived       Fare
# 0       0.0  22.117887
# 1       1.0  48.395408

# %%
grid = sns.FacetGrid(df, hue='Survived', height=4, aspect=1.5)
grid.map(plt.hist, 'Fare', alpha=.5, bins=range(0,210,10))
grid.add_legend()
plt.show()

# %%
df[['Fare', 'Survived']].groupby(['Fare'],as_index=False).mean().plot.scatter('Fare','Survived')
plt.show()

# %%
# bin Fare into five intervals with equal amount of people
df['Fare-bin'] = pd.qcut(df.Fare,5,labels=[1,2,3,4,5]).astype(int)

# inspect the correlation between Fare-bin and Survived
df[['Fare-bin', 'Survived']].groupby(['Fare-bin'], as_index=False).mean()
# Out:
#    Fare-bin  Survived
# 0         1  0.217877
# 1         2  0.201087
# 2         3  0.426901
# 3         4  0.443243
# 4         5  0.645349

# %%
df = df.drop(labels=['Cabin'], axis=1)

# %%
df.Embarked.isnull().sum(axis=0)
# Out:
# 2

# %%
df.describe(include=['O'])
# Out:
#        Ticket Embarked Title
# count    1309     1307  1309
# unique     16        3     5
# top         3        S    Mr
# freq      429      914   757

# %%
df.Embarked.fillna('S' , inplace=True )

# %%
df[['Embarked', 'Survived','Pclass','Fare', 'Age', 'Sex']].groupby(['Embarked'], as_index=False).mean()
# Out:
#   Embarked  Survived    Pclass       Fare        Age       Sex
# 0        C  0.553571  1.851852  62.336267  32.332170  0.418519
# 1        Q  0.389610  2.894309  12.409012  28.630000  0.487805
# 2        S  0.339009  2.344978  27.512485  29.298151  0.319869

# %%
df = df.drop(labels='Embarked', axis=1)

# %%
grid = sns.FacetGrid(df, col='Title', height=3, aspect=0.8, sharey=False)
grid.map(plt.hist, 'Age', alpha=.5, bins=range(0,105,5))
plt.show()

# %%
df[['Title', 'Age']].groupby(['Title']).mean()
# Out:
#               Age
# Title
# Master   5.482642
# Miss    21.795236
# Mr      32.252151
# Mrs     36.930636
# Others  45.074074

# %%
df[['Title', 'Age']].groupby(['Title']).std()
# Out:
#               Age
# Title
# Master   4.161554
# Miss    12.192794
# Mr      12.422089
# Mrs     12.872625
# Others  11.303253

# %%
grid = sns.FacetGrid(df, col='Fare-bin', height=3, aspect=0.8, sharey=False)
grid.map(plt.hist, 'Age', alpha=.5, bins=range(0,105,5))
plt.show()

# %%
df[['Fare-bin', 'Age']].groupby(['Fare-bin']).mean()
# Out:
#                 Age
# Fare-bin
# 1         27.848315
# 2         27.898241
# 3         26.144009
# 4         30.728604
# 5         35.877913

# %%
df[['Fare-bin', 'Age']].groupby(['Fare-bin']).std()
# Out:
#                 Age
# Fare-bin
# 1         10.812580
# 2         10.995650
# 3         13.523208
# 4         17.466022
# 5         15.150724

# %%
grid = sns.FacetGrid(df, col='SibSp', col_wrap=4, height=3.0, aspect=0.8, sharey=False)
grid.map(plt.hist, 'Age', alpha=.5, bins=range(0,105,5))
plt.show()

# %%
df[['SibSp', 'Age']].groupby(['SibSp']).mean()
# Out:
#              Age
# SibSp
# 0      30.921766
# 1      31.058071
# 2      23.569444
# 3      16.312500
# 4       8.772727
# 5      10.166667
# 8      14.500000

# %%
df[['SibSp', 'Age']].groupby(['SibSp']).std()
# Out:
#              Age
# SibSp
# 0      13.059751
# 1      15.974482
# 2      14.910640
# 3      11.824938
# 4       8.005545
# 5       5.192944
# 8            NaN

# %%
grid = sns.FacetGrid(df, col='Parch', col_wrap=4, height=3.0, aspect=0.8, sharey=False)
grid.map(plt.hist, 'Age', alpha=.5, bins=range(0,105,5))
plt.show()
# Out:
# /usr/local/lib/python3.9/dist-packages/matplotlib/axes/_axes.py:6762: RuntimeWarning: All-NaN slice encountered
#   xmin = min(xmin, np.nanmin(xi))
# /usr/local/lib/python3.9/dist-packages/matplotlib/axes/_axes.py:6763: RuntimeWarning: All-NaN slice encountered
#   xmax = max(xmax, np.nanmax(xi))

# %%
df[['Parch', 'Age']].groupby(['Parch']).mean()
# Out:
#              Age
# Parch
# 0      31.969401
# 1      24.965625
# 2      18.975979
# 3      38.875000
# 4      47.600000
# 5      39.333333
# 6      41.500000
# 9            NaN

# %%
df[['Parch', 'Age']].groupby(['Parch']).std()
# Out:
#              Age
# Parch
# 0      12.422617
# 1      18.410885
# 2      14.564066
# 3      16.295815
# 4      14.432602
# 5       1.032796
# 6       2.121320
# 9            NaN

# %%
df_sub = df[['Age','Master','Miss','Mr','Mrs','Others','Fare-bin','SibSp']]

X_train  = df_sub.dropna().drop('Age', axis=1)
y_train  = df['Age'].dropna()
X_test = df_sub.loc[np.isnan(df.Age)].drop('Age', axis=1)

regressor = RandomForestRegressor(n_estimators = 300)
regressor.fit(X_train, y_train)
y_pred = np.round(regressor.predict(X_test),1)
df.Age.loc[df.Age.isnull()] = y_pred
# Out:
# <ipython-input-80-0117b1e62277>:10: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df.Age.loc[df.Age.isnull()] = y_pred

# %%
bins = [ 0, 4, 12, 18, 30, 50, 65, 100] # This is somewhat arbitrary
age_index = (1,2,3,4,5,6,7) #('baby','child','teenager','young','mid-age','over-50','senior')
df['Age-bin'] = pd.cut(df.Age, bins, labels=age_index).astype(int)

df[['Age-bin', 'Survived']].groupby(['Age-bin'],as_index=False).mean()
# Out:
#    Age-bin  Survived
# 0        1  0.675000
# 1        2  0.452381
# 2        3  0.402597
# 3        4  0.315789
# 4        5  0.427083
# 5        6  0.375000
# 6        7  0.125000

# %%
df[['Ticket', 'Survived']].groupby(['Ticket'], as_index=False).mean()
# Out:
#    Ticket  Survived
# 0       1  0.630137
# 1       2  0.464481
# 2       3  0.239203
# 3       4  0.200000
# 4       5  0.000000
# 5       6  0.166667
# 6       7  0.111111
# 7       8  0.000000
# 8       9  1.000000
# 9       A  0.068966
# 10      C  0.340426
# 11      F  0.571429
# 12      L  0.250000
# 13      P  0.646154
# 14      S  0.323077
# 15      W  0.153846

# %%
df['Ticket'].value_counts()
# Out:
# 3    429
# 2    278
# 1    210
# P     98
# S     98
# C     77
# A     42
# W     19
# 7     13
# F     13
# 4     11
# 6      9
# L      5
# 5      3
# 9      2
# 8      2
# Name: Ticket, dtype: int64

# %%
df['Ticket'] = df['Ticket'].replace(['A','W','F','L','5','6','7','8','9'], '4')

df[['Ticket', 'Survived']].groupby(['Ticket'], as_index=False).mean()
# Out:
#   Ticket  Survived
# 0      1  0.630137
# 1      2  0.464481
# 2      3  0.239203
# 3      4  0.166667
# 4      C  0.340426
# 5      P  0.646154
# 6      S  0.323077

# %%
df = pd.get_dummies(df,columns=['Ticket'])

# %%
df = df.drop(labels=['SibSp','Parch','Age','Fare','Title'], axis=1)
y_train = df[0:891]['Survived'].values
X_train = df[0:891].drop(['Survived','PassengerId'], axis=1).values
X_test  = df[891:].drop(['Survived','PassengerId'], axis=1).values

# %%
model = Sequential()


model.add(Dense(9, kernel_initializer = 'uniform', activation = 'relu', input_dim = 17))
model.add(Dense(9, kernel_initializer = 'uniform', activation = 'relu'))
model.add(Dense(5, kernel_initializer = 'uniform', activation = 'relu'))
model.add(Dense(1, kernel_initializer = 'uniform', activation = 'sigmoid'))


model.summary()
# Out:
# Model: "sequential"
# _________________________________________________________________
#  Layer (type)                Output Shape              Param #
# =================================================================
#  dense (Dense)               (None, 9)                 162
#
#  dense_1 (Dense)             (None, 9)                 90
#
#  dense_2 (Dense)             (None, 5)                 50
#
#  dense_3 (Dense)             (None, 1)                 6
#
# =================================================================
# Total params: 308
# Trainable params: 308
# Non-trainable params: 0
# _________________________________________________________________

# %%
model.compile(optimizer = 'adam', loss = 'binary_crossentropy', metrics = ['accuracy'])


model.fit(X_train, y_train, batch_size = 32, epochs = 200)
# Out:
# Epoch 1/200
# 28/28 [==============================] - 2s 2ms/step - loss: 0.6916 - accuracy: 0.6117
# Epoch 2/200
# 28/28 [==============================] - 0s 3ms/step - loss: 0.6890 - accuracy: 0.6162
# Epoch 3/200
# 28/28 [==============================] - 0s 2ms/step - loss: 0.6868 - accuracy: 0.6162
# Epoch 4/200
# 28/28 [==============================] - 0s 2ms/step - loss: 0.6847 - accuracy: 0.6162
# Epoch 5/200
# 28/28 [==============================] - 0s 2ms/step - loss: 0.6829 - accuracy: 0.6162
# Epoch 6/200
# 28/28 [==============================] - 0s 2ms/step - loss: 0.6811 - accuracy: 0.6162
# Epoch 7/200
# 28/28 [==============================] - 0s 2ms/step - loss: 0.6796 - accuracy: 0.6162
# Epoch 8/200
# 28/28 [==============================] - 0s 2ms/step - loss: 0.6781 - accuracy: 0.6162
# Epoch 9/200
# 28/28 [==============================] - 0s 2ms/step - loss: 0.6768 - accuracy: 0.6162
# Epoch 10/200
# 28/28 [==============================] - 0s 2ms/step - loss: 0.6757 - accuracy: 0.6162
# Epoch 11/200
# 28/28 [==============================] - 0s 2ms/step - loss: 0.6747 - accuracy: 0.6162
# Epoch 12/200
# 28/28 [==============================] - 0s 2ms/step - loss: 0.6737 - accuracy: 0.6162
# Epoch 13/200
# 28/28 [==============================] - 0s 2ms/step - loss: 0.6728 - accuracy: 0.6162
# Epoch 14/200
# 28/28 [==============================] - 0s 2ms/step - loss: 0.6721 - accuracy: 0.6162
# Epoch 15/200
# 28/28 [==============================] - 0s 2ms/step - loss: 0.6714 - accuracy: 0.6162
# Epoch 16/200
# 28/28 [==============================] - 0s 3ms/step - loss: 0.6708 - accuracy: 0.6162
# Epoch 17/200
# 28/28 [==============================] - 0s 3ms/step - loss: 0.6702 - accuracy: 0.6162
# Epoch 18/200
# 28/28 [==============================] - 0s 4ms/step - loss: 0.6697 - accuracy: 0.6162
# Epoch 19/200
# 28/28 [==============================] - 0s 3ms/step - loss: 0.6693 - accuracy: 0.6162
# Epoch 20/200
# 28/28 [==============================] - 0s 3ms/step - loss: 0.6689 - accuracy: 0.6162
# Epoch 21/200
# 28/28 [==============================] - 0s 3ms/step - loss: 0.6685 - accuracy: 0.6162
# Epoch 22/200
# 28/28 [==============================] - 0s 3ms/step - loss: 0.6682 - accuracy: 0.6162
# Epoch 23/200
# 28/28 [==============================] - 0s 3ms/step - loss: 0.6679 - accuracy: 0.6162
# Epoch 24/200
# 28/28 [==============================] - 0s 3ms/step - loss: 0.6677 - accuracy: 0.6162
# Epoch 25/200
# 28/28 [==============================] - 0s 3ms/step - loss: 0.6675 - accuracy: 0.6162
# Epoch 26/200
# 28/28 [==============================] - 0s 3ms/step - loss: 0.6673 - accuracy: 0.6162
# Epoch 27/200
# 28/28 [==============================] - 0s 3ms/step - loss: 0.6671 - accuracy: 0.6162
# Epoch 28/200
# 28/28 [==============================] - 0s 3ms/step - loss: 0.6670 - accuracy: 0.6162
# Epoch 29/200
# 28/28 [==============================] - 0s 3ms/step - loss: 0.6668 - accuracy: 0.6162
# Epoch 30/200
# 28/28 [==============================] - 0s 4ms/step - loss: 0.6667 - accuracy: 0.6162
# Epoch 31/200
# 28/28 [==============================] - 0s 3ms/step - loss: 0.6666 - accuracy: 0.6162
# Epoch 32/200
# 28/28 [==============================] - 0s 3ms/step - loss: 0.6665 - accuracy: 0.6162
# Epoch 33/200
# 28/28 [==============================] - 0s 4ms/step - loss: 0.6665 - accuracy: 0.6162
# Epoch 34/200
# 28/28 [==============================] - 0s 3ms/step - loss: 0.6664 - accuracy: 0.6162
# Epoch 35/200
# 28/28 [==============================] - 0s 3ms/step - loss: 0.6663 - accuracy: 0.6162
# Epoch 36/200
# 28/28 [==============================] - 0s 3ms/step - loss: 0.6663 - accuracy: 0.6162
# Epoch 37/200
# 28/28 [==============================] - 0s 3ms/step - loss: 0.6662 - accuracy: 0.6162
# Epoch 38/200
# 28/28 [==============================] - 0s 3ms/step - loss: 0.6662 - accuracy: 0.6162
# Epoch 39/200
# 28/28 [==============================] - 0s 3ms/step - loss: 0.6662 - accuracy: 0.6162
# Epoch 40/200
# 28/28 [==============================] - 0s 3ms/step - loss: 0.6661 - accuracy: 0.6162
# Epoch 41/200
# 28/28 [==============================] - 0s 3ms/step - loss: 0.6661 - accuracy: 0.6162
# Epoch 42/200
# 28/28 [==============================] - 0s 3ms/step - loss: 0.6661 - accuracy: 0.6162
# Epoch 43/200
# 28/28 [==============================] - 0s 3ms/step - loss: 0.6661 - accuracy: 0.6162
# Epoch 44/200
# 28/28 [==============================] - 0s 3ms/step - loss: 0.6660 - accuracy: 0.6162
# Epoch 45/200
# 28/28 [==============================] - 0s 3ms/step - loss: 0.6660 - accuracy: 0.6162
# Epoch 46/200
# 28/28 [==============================] - 0s 3ms/step - loss: 0.6660 - accuracy: 0.6162
# Epoch 47/200
# 28/28 [==============================] - 0s 3ms/step - loss: 0.6660 - accuracy: 0.6162
# Epoch 48/200
# 28/28 [==============================] - 0s 2ms/step - loss: 0.6660 - accuracy: 0.6162
# Epoch 49/200
# 28/28 [==============================] - 0s 2ms/step - loss: 0.6660 - accuracy: 0.6162
# Epoch 50/200
# 28/28 [==============================] - 0s 2ms/step - loss: 0.6660 - accuracy: 0.6162
# Epoch 51/200
# 28/28 [==============================] - 0s 2ms/step - loss: 0.6660 - accuracy: 0.6162
# Epoch 52/200
# 28/28 [==============================] - 0s 2ms/step - loss: 0.6660 - accuracy: 0.6162
# Epoch 53/200
# 28/28 [==============================] - 0s 3ms/step - loss: 0.6660 - accuracy: 0.6162
# Epoch 54/200
# 28/28 [==============================] - 0s 2ms/step - loss: 0.6660 - accuracy: 0.6162
# Epoch 55/200
# 28/28 [==============================] - 0s 2ms/step - loss: 0.6659 - accuracy: 0.6162
# Epoch 56/200
# 28/28 [==============================] - 0s 2ms/step - loss: 0.6659 - accuracy: 0.6162
# Epoch 57/200
# 28/28 [==============================] - 0s 3ms/step - loss: 0.6659 - accuracy: 0.6162
# Epoch 58/200
# 28/28 [==============================] - 0s 2ms/step - loss: 0.6660 - accuracy: 0.6162
# Epoch 59/200
# 28/28 [==============================] - 0s 2ms/step - loss: 0.6660 - accuracy: 0.6162
# Epoch 60/200
# 28/28 [==============================] - 0s 2ms/step - loss: 0.6659 - accuracy: 0.6162
# Epoch 61/200
# 28/28 [==============================] - 0s 3ms/step - loss: 0.6659 - accuracy: 0.6162
# Epoch 62/200
# 28/28 [==============================] - 0s 2ms/step - loss: 0.6659 - accuracy: 0.6162
# Epoch 63/200
# 28/28 [==============================] - 0s 2ms/step - loss: 0.6659 - accuracy: 0.6162
# Epoch 64/200
# 28/28 [==============================] - 0s 2ms/step - loss: 0.6660 - accuracy: 0.6162
# Epoch 65/200
# 28/28 [==============================] - 0s 2ms/step - loss: 0.6660 - accuracy: 0.6162
# Epoch 66/200
# 28/28 [==============================] - 0s 2ms/step - loss: 0.6659 - accuracy: 0.6162
# Epoch 67/200
# 28/28 [==============================] - 0s 2ms/step - loss: 0.6659 - accuracy: 0.6162
# Epoch 68/200
# 28/28 [==============================] - 0s 2ms/step - loss: 0.6659 - accuracy: 0.6162
# Epoch 69/200
# 28/28 [==============================] - 0s 2ms/step - loss: 0.6659 - accuracy: 0.6162
# Epoch 70/200
# 28/28 [==============================] - 0s 2ms/step - loss: 0.6659 - accuracy: 0.6162
# Epoch 71/200
# 28/28 [==============================] - 0s 2ms/step - loss: 0.6659 - accuracy: 0.6162
# Epoch 72/200
# 28/28 [==============================] - 0s 2ms/step - loss: 0.6659 - accuracy: 0.6162
# Epoch 73/200
# 28/28 [==============================] - 0s 2ms/step - loss: 0.6660 - accuracy: 0.6162
# Epoch 74/200
# 28/28 [==============================] - 0s 2ms/step - loss: 0.6659 - accuracy: 0.6162
# Epoch 75/200
# 28/28 [==============================] - 0s 2ms/step - loss: 0.6659 - accuracy: 0.6162
# Epoch 76/200
# 28/28 [==============================] - 0s 2ms/step - loss: 0.6659 - accuracy: 0.6162
# Epoch 77/200
# 28/28 [==============================] - 0s 2ms/step - loss: 0.6659 - accuracy: 0.6162
# Epoch 78/200
# 28/28 [==============================] - 0s 2ms/step - loss: 0.6659 - accuracy: 0.6162
# Epoch 79/200
# 28/28 [==============================] - 0s 3ms/step - loss: 0.6660 - accuracy: 0.6162
# Epoch 80/200
# 28/28 [==============================] - 0s 3ms/step - loss: 0.6659 - accuracy: 0.6162
# Epoch 81/200
# 28/28 [==============================] - 0s 2ms/step - loss: 0.6659 - accuracy: 0.6162
# Epoch 82/200
# 28/28 [==============================] - 0s 2ms/step - loss: 0.6659 - accuracy: 0.6162
# Epoch 83/200
# 28/28 [==============================] - 0s 3ms/step - loss: 0.6660 - accuracy: 0.6162
# Epoch 84/200
# 28/28 [==============================] - 0s 3ms/step - loss: 0.6659 - accuracy: 0.6162
# Epoch 85/200
# 28/28 [==============================] - 0s 2ms/step - loss: 0.6659 - accuracy: 0.6162
# Epoch 86/200
# 28/28 [==============================] - 0s 2ms/step - loss: 0.6659 - accuracy: 0.6162
# Epoch 87/200
# 28/28 [==============================] - 0s 3ms/step - loss: 0.6659 - accuracy: 0.6162
# Epoch 88/200
# 28/28 [==============================] - 0s 3ms/step - loss: 0.6659 - accuracy: 0.6162
# Epoch 89/200
# 28/28 [==============================] - 0s 2ms/step - loss: 0.6659 - accuracy: 0.6162
# Epoch 90/200
# 28/28 [==============================] - 0s 3ms/step - loss: 0.6659 - accuracy: 0.6162
# Epoch 91/200
# 28/28 [==============================] - 0s 2ms/step - loss: 0.6659 - accuracy: 0.6162
# Epoch 92/200
# 28/28 [==============================] - 0s 3ms/step - loss: 0.6659 - accuracy: 0.6162
# Epoch 93/200
# 28/28 [==============================] - 0s 3ms/step - loss: 0.6659 - accuracy: 0.6162
# Epoch 94/200
# 28/28 [==============================] - 0s 2ms/step - loss: 0.6659 - accuracy: 0.6162
# Epoch 95/200
# 28/28 [==============================] - 0s 3ms/step - loss: 0.6659 - accuracy: 0.6162
# Epoch 96/200
# 28/28 [==============================] - 0s 2ms/step - loss: 0.6660 - accuracy: 0.6162
# Epoch 97/200
# 28/28 [==============================] - 0s 3ms/step - loss: 0.6659 - accuracy: 0.6162
# Epoch 98/200
# 28/28 [==============================] - 0s 2ms/step - loss: 0.6659 - accuracy: 0.6162
# Epoch 99/200
# 28/28 [==============================] - 0s 3ms/step - loss: 0.6659 - accuracy: 0.6162
# Epoch 100/200
# 28/28 [==============================] - 0s 3ms/step - loss: 0.6659 - accuracy: 0.6162
# Epoch 101/200
# 28/28 [==============================] - 0s 2ms/step - loss: 0.6660 - accuracy: 0.6162
# Epoch 102/200
# 28/28 [==============================] - 0s 3ms/step - loss: 0.6660 - accuracy: 0.6162
# Epoch 103/200
# 28/28 [==============================] - 0s 2ms/step - loss: 0.6659 - accuracy: 0.6162
# Epoch 104/200
# 28/28 [==============================] - 0s 2ms/step - loss: 0.6659 - accuracy: 0.6162
# Epoch 105/200
# 28/28 [==============================] - 0s 2ms/step - loss: 0.6659 - accuracy: 0.6162
# Epoch 106/200
# 28/28 [==============================] - 0s 2ms/step - loss: 0.6659 - accuracy: 0.6162
# Epoch 107/200
# 28/28 [==============================] - 0s 2ms/step - loss: 0.6659 - accuracy: 0.6162
# Epoch 108/200
# 28/28 [==============================] - 0s 2ms/step - loss: 0.6659 - accuracy: 0.6162
# Epoch 109/200
# 28/28 [==============================] - 0s 2ms/step - loss: 0.6660 - accuracy: 0.6162
# Epoch 110/200
# 28/28 [==============================] - 0s 2ms/step - loss: 0.6659 - accuracy: 0.6162
# Epoch 111/200
# 28/28 [==============================] - 0s 2ms/step - loss: 0.6659 - accuracy: 0.6162
# Epoch 112/200
# 28/28 [==============================] - 0s 2ms/step - loss: 0.6659 - accuracy: 0.6162
# Epoch 113/200
# 28/28 [==============================] - 0s 2ms/step - loss: 0.6659 - accuracy: 0.6162
# Epoch 114/200
# 28/28 [==============================] - 0s 2ms/step - loss: 0.6659 - accuracy: 0.6162
# Epoch 115/200
# 28/28 [==============================] - 0s 2ms/step - loss: 0.6659 - accuracy: 0.6162
# Epoch 116/200
# 28/28 [==============================] - 0s 2ms/step - loss: 0.6659 - accuracy: 0.6162
# Epoch 117/200
# 28/28 [==============================] - 0s 2ms/step - loss: 0.6659 - accuracy: 0.6162
# Epoch 118/200
# 28/28 [==============================] - 0s 2ms/step - loss: 0.6660 - accuracy: 0.6162
# Epoch 119/200
# 28/28 [==============================] - 0s 2ms/step - loss: 0.6659 - accuracy: 0.6162
# Epoch 120/200
# 28/28 [==============================] - 0s 2ms/step - loss: 0.6659 - accuracy: 0.6162
# Epoch 121/200
# 28/28 [==============================] - 0s 2ms/step - loss: 0.6660 - accuracy: 0.6162
# Epoch 122/200
# 28/28 [==============================] - 0s 2ms/step - loss: 0.6660 - accuracy: 0.6162
# Epoch 123/200
# 28/28 [==============================] - 0s 2ms/step - loss: 0.6659 - accuracy: 0.6162
# Epoch 124/200
# 28/28 [==============================] - 0s 2ms/step - loss: 0.6659 - accuracy: 0.6162
# Epoch 125/200
# 28/28 [==============================] - 0s 2ms/step - loss: 0.6659 - accuracy: 0.6162
# Epoch 126/200
# 28/28 [==============================] - 0s 2ms/step - loss: 0.6659 - accuracy: 0.6162
# Epoch 127/200
# 28/28 [==============================] - 0s 3ms/step - loss: 0.6659 - accuracy: 0.6162
# Epoch 128/200
# 28/28 [==============================] - 0s 3ms/step - loss: 0.6659 - accuracy: 0.6162
# Epoch 129/200
# 28/28 [==============================] - 0s 2ms/step - loss: 0.6660 - accuracy: 0.6162
# Epoch 130/200
# 28/28 [==============================] - 0s 2ms/step - loss: 0.6659 - accuracy: 0.6162
# Epoch 131/200
# 28/28 [==============================] - 0s 2ms/step - loss: 0.6659 - accuracy: 0.6162
# Epoch 132/200
# 28/28 [==============================] - 0s 2ms/step - loss: 0.6659 - accuracy: 0.6162
# Epoch 133/200
# 28/28 [==============================] - 0s 2ms/step - loss: 0.6659 - accuracy: 0.6162
# Epoch 134/200
# 28/28 [==============================] - 0s 2ms/step - loss: 0.6659 - accuracy: 0.6162
# Epoch 135/200
# 28/28 [==============================] - 0s 2ms/step - loss: 0.6659 - accuracy: 0.6162
# Epoch 136/200
# 28/28 [==============================] - 0s 2ms/step - loss: 0.6659 - accuracy: 0.6162
# Epoch 137/200
# 28/28 [==============================] - 0s 2ms/step - loss: 0.6660 - accuracy: 0.6162
# Epoch 138/200
# 28/28 [==============================] - 0s 2ms/step - loss: 0.6659 - accuracy: 0.6162
# Epoch 139/200
# 28/28 [==============================] - 0s 2ms/step - loss: 0.6659 - accuracy: 0.6162
# Epoch 140/200
# 28/28 [==============================] - 0s 2ms/step - loss: 0.6660 - accuracy: 0.6162
# Epoch 141/200
# 28/28 [==============================] - 0s 2ms/step - loss: 0.6659 - accuracy: 0.6162
# Epoch 142/200
# 28/28 [==============================] - 0s 3ms/step - loss: 0.6659 - accuracy: 0.6162
# Epoch 143/200
# 28/28 [==============================] - 0s 2ms/step - loss: 0.6659 - accuracy: 0.6162
# Epoch 144/200
# 28/28 [==============================] - 0s 3ms/step - loss: 0.6659 - accuracy: 0.6162
# Epoch 145/200
# 28/28 [==============================] - 0s 3ms/step - loss: 0.6659 - accuracy: 0.6162
# Epoch 146/200
# 28/28 [==============================] - 0s 2ms/step - loss: 0.6659 - accuracy: 0.6162
# Epoch 147/200
# 28/28 [==============================] - 0s 2ms/step - loss: 0.6659 - accuracy: 0.6162
# Epoch 148/200
# 28/28 [==============================] - 0s 2ms/step - loss: 0.6659 - accuracy: 0.6162
# Epoch 149/200
# 28/28 [==============================] - 0s 2ms/step - loss: 0.6659 - accuracy: 0.6162
# Epoch 150/200
# 28/28 [==============================] - 0s 2ms/step - loss: 0.6659 - accuracy: 0.6162
# Epoch 151/200
# 28/28 [==============================] - 0s 2ms/step - loss: 0.6659 - accuracy: 0.6162
# Epoch 152/200
# 28/28 [==============================] - 0s 2ms/step - loss: 0.6659 - accuracy: 0.6162
# Epoch 153/200
# 28/28 [==============================] - 0s 2ms/step - loss: 0.6659 - accuracy: 0.6162
# Epoch 154/200
# 28/28 [==============================] - 0s 2ms/step - loss: 0.6659 - accuracy: 0.6162
# Epoch 155/200
# 28/28 [==============================] - 0s 2ms/step - loss: 0.6659 - accuracy: 0.6162
# Epoch 156/200
# 28/28 [==============================] - 0s 2ms/step - loss: 0.6659 - accuracy: 0.6162
# Epoch 157/200
# 28/28 [==============================] - 0s 3ms/step - loss: 0.6659 - accuracy: 0.6162
# Epoch 158/200
# 28/28 [==============================] - 0s 2ms/step - loss: 0.6659 - accuracy: 0.6162
# Epoch 159/200
# 28/28 [==============================] - 0s 3ms/step - loss: 0.6659 - accuracy: 0.6162
# Epoch 160/200
# 28/28 [==============================] - 0s 2ms/step - loss: 0.6659 - accuracy: 0.6162
# Epoch 161/200
# 28/28 [==============================] - 0s 2ms/step - loss: 0.6659 - accuracy: 0.6162
# Epoch 162/200
# 28/28 [==============================] - 0s 2ms/step - loss: 0.6659 - accuracy: 0.6162
# Epoch 163/200
# 28/28 [==============================] - 0s 2ms/step - loss: 0.6659 - accuracy: 0.6162
# Epoch 164/200
# 28/28 [==============================] - 0s 2ms/step - loss: 0.6659 - accuracy: 0.6162
# Epoch 165/200
# 28/28 [==============================] - 0s 2ms/step - loss: 0.6659 - accuracy: 0.6162
# Epoch 166/200
# 28/28 [==============================] - 0s 2ms/step - loss: 0.6659 - accuracy: 0.6162
# Epoch 167/200
# 28/28 [==============================] - 0s 2ms/step - loss: 0.6659 - accuracy: 0.6162
# Epoch 168/200
# 28/28 [==============================] - 0s 3ms/step - loss: 0.6659 - accuracy: 0.6162
# Epoch 169/200
# 28/28 [==============================] - 0s 2ms/step - loss: 0.6659 - accuracy: 0.6162
# Epoch 170/200
# 28/28 [==============================] - 0s 2ms/step - loss: 0.6659 - accuracy: 0.6162
# Epoch 171/200
# 28/28 [==============================] - 0s 2ms/step - loss: 0.6659 - accuracy: 0.6162
# Epoch 172/200
# 28/28 [==============================] - 0s 3ms/step - loss: 0.6659 - accuracy: 0.6162
# Epoch 173/200
# 28/28 [==============================] - 0s 2ms/step - loss: 0.6659 - accuracy: 0.6162
# Epoch 174/200
# 28/28 [==============================] - 0s 2ms/step - loss: 0.6659 - accuracy: 0.6162
# Epoch 175/200
# 28/28 [==============================] - 0s 2ms/step - loss: 0.6659 - accuracy: 0.6162
# Epoch 176/200
# 28/28 [==============================] - 0s 2ms/step - loss: 0.6659 - accuracy: 0.6162
# Epoch 177/200
# 28/28 [==============================] - 0s 3ms/step - loss: 0.6659 - accuracy: 0.6162
# Epoch 178/200
# 28/28 [==============================] - 0s 2ms/step - loss: 0.6659 - accuracy: 0.6162
# Epoch 179/200
# 28/28 [==============================] - 0s 2ms/step - loss: 0.6659 - accuracy: 0.6162
# Epoch 180/200
# 28/28 [==============================] - 0s 2ms/step - loss: 0.6659 - accuracy: 0.6162
# Epoch 181/200
# 28/28 [==============================] - 0s 2ms/step - loss: 0.6659 - accuracy: 0.6162
# Epoch 182/200
# 28/28 [==============================] - 0s 2ms/step - loss: 0.6659 - accuracy: 0.6162
# Epoch 183/200
# 28/28 [==============================] - 0s 2ms/step - loss: 0.6659 - accuracy: 0.6162
# Epoch 184/200
# 28/28 [==============================] - 0s 2ms/step - loss: 0.6659 - accuracy: 0.6162
# Epoch 185/200
# 28/28 [==============================] - 0s 2ms/step - loss: 0.6659 - accuracy: 0.6162
# Epoch 186/200
# 28/28 [==============================] - 0s 3ms/step - loss: 0.6659 - accuracy: 0.6162
# Epoch 187/200
# 28/28 [==============================] - 0s 3ms/step - loss: 0.6659 - accuracy: 0.6162
# Epoch 188/200
# 28/28 [==============================] - 0s 4ms/step - loss: 0.6659 - accuracy: 0.6162
# Epoch 189/200
# 28/28 [==============================] - 0s 3ms/step - loss: 0.6659 - accuracy: 0.6162
# Epoch 190/200
# 28/28 [==============================] - 0s 3ms/step - loss: 0.6660 - accuracy: 0.6162
# Epoch 191/200
# 28/28 [==============================] - 0s 3ms/step - loss: 0.6659 - accuracy: 0.6162
# Epoch 192/200
# 28/28 [==============================] - 0s 3ms/step - loss: 0.6659 - accuracy: 0.6162
# Epoch 193/200
# 28/28 [==============================] - 0s 3ms/step - loss: 0.6660 - accuracy: 0.6162
# Epoch 194/200
# 28/28 [==============================] - 0s 3ms/step - loss: 0.6660 - accuracy: 0.6162
# Epoch 195/200
# 28/28 [==============================] - 0s 3ms/step - loss: 0.6659 - accuracy: 0.6162
# Epoch 196/200
# 28/28 [==============================] - 0s 3ms/step - loss: 0.6659 - accuracy: 0.6162
# Epoch 197/200
# 28/28 [==============================] - 0s 3ms/step - loss: 0.6659 - accuracy: 0.6162
# Epoch 198/200
# 28/28 [==============================] - 0s 3ms/step - loss: 0.6659 - accuracy: 0.6162
# Epoch 199/200
# 28/28 [==============================] - 0s 3ms/step - loss: 0.6660 - accuracy: 0.6162
# Epoch 200/200
# 28/28 [==============================] - 0s 3ms/step - loss: 0.6660 - accuracy: 0.6162

# %%
y_pred = model.predict(X_test)
y_final = (y_pred > 0.5).astype(int).reshape(X_test.shape[0])

output = pd.DataFrame({'PassengerId': df_test['PassengerId'], 'Survived': y_final})
output.to_csv('prediction.csv', index=False)
# Out:
# 14/14 [==============================] - 1s 6ms/step

# %%
corr_matrix = df.corr()

# %%
sns.heatmap(corr_matrix, vmin=-1, vmax=1, center=0, cmap='coolwarm', annot=True, fmt='.2f', square=True)
plt.show()
