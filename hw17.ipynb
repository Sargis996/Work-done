# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
import math

from sklearn.preprocessing import MinMaxScaler
from sklearn.metrics import mean_squared_error

from keras.models import Sequential
from keras.layers import Dense
from keras.layers import LSTM

# %%
data = pd.read_csv("/content/bitcoin_ticker.csv")
data.head()
# Out:
#       date_id          datetime_id    market  rpt_key        last    diff_24h  \
# 0  2017-05-31  2017-06-01 00:00:00  bitstamp  btc_eur     1996.72     2029.99
# 1  2017-05-31  2017-06-01 00:00:00  bitflyer  btc_jpy   267098.00   269649.00
# 2  2017-05-31  2017-06-01 00:00:00    korbit  btc_krw  3003500.00  3140000.00
# 3  2017-05-31  2017-06-01 00:00:00  bitstamp  btc_usd     2237.40     2239.37
# 4  2017-05-31  2017-06-01 00:00:00    okcoin  btc_usd     2318.82     2228.70
#
#    diff_per_24h         bid         ask         low        high        volume  \
# 0     -1.638924     2005.50     2005.56     1950.00     2063.73   2314.500750
# 1     -0.946045   267124.00   267267.00   267124.00   267267.00  70922.880112
# 2     -4.347134  3003500.00  3004000.00  3002000.00  3209500.00   6109.752872
# 3     -0.087971     2233.09     2237.40     2154.28     2293.46  13681.282017
# 4      4.043613     2319.40     2319.99     2129.78     2318.82   4241.641516
#
#             created_at           updated_at
# 0  2017-05-31 14:59:36  2017-05-31 14:59:36
# 1  2017-05-31 14:59:36  2017-05-31 14:59:36
# 2  2017-05-31 14:59:36  2017-05-31 14:59:36
# 3  2017-05-31 14:59:36  2017-05-31 14:59:36
# 4  2017-05-31 14:59:36  2017-05-31 14:59:36

# %%
data['rpt_key'].value_counts()
# Out:
# btc_usd       125438
# btc_eur        62719
# btc_jpy        62719
# btc_krw        62719
# etc_krw        62719
# eth_btc        62719
# eth_krw        62719
# fx_btc_jpy     62719
# ltc_usd        62719
# Name: rpt_key, dtype: int64

# %%
df = data.loc[(data['rpt_key'] == 'btc_usd')]
df.head()
# Out:
#        date_id          datetime_id    market  rpt_key     last  diff_24h  \
# 3   2017-05-31  2017-06-01 00:00:00  bitstamp  btc_usd  2237.40   2239.37
# 4   2017-05-31  2017-06-01 00:00:00    okcoin  btc_usd  2318.82   2228.70
# 15  2017-06-01  2017-06-01 00:01:00  bitstamp  btc_usd  2248.39   2242.44
# 16  2017-06-01  2017-06-01 00:01:00    okcoin  btc_usd  2320.42   2228.40
# 23  2017-06-01  2017-06-01 00:02:00  bitstamp  btc_usd  2248.35   2238.58
#
#     diff_per_24h      bid      ask      low     high        volume  \
# 3      -0.087971  2233.09  2237.40  2154.28  2293.46  13681.282017
# 4       4.043613  2319.40  2319.99  2129.78  2318.82   4241.641516
# 15      0.265336  2247.77  2248.38  2154.28  2293.46  13701.698603
# 16      4.129420  2320.99  2321.49  2129.78  2322.00   4260.261516
# 23      0.436437  2248.35  2248.69  2154.28  2293.46  13742.110913
#
#              created_at           updated_at
# 3   2017-05-31 14:59:36  2017-05-31 14:59:36
# 4   2017-05-31 14:59:36  2017-05-31 14:59:36
# 15  2017-05-31 15:00:36  2017-05-31 15:00:36
# 16  2017-05-31 15:00:36  2017-05-31 15:00:36
# 23  2017-05-31 15:01:36  2017-05-31 15:01:36

# %%
df = df.reset_index(drop=True)
df['datetime'] = pd.to_datetime(df['datetime_id'])
df = df.loc[df['datetime'] > pd.to_datetime('2017-06-28 00:00:00')]
df = df[['datetime', 'last', 'diff_24h', 'diff_per_24h', 'bid', 'ask', 'low', 'high', 'volume']]
df.head()
# Out:
#                  datetime     last  diff_24h  diff_per_24h      bid      ask  \
# 77762 2017-06-28 00:01:00  2344.00   2491.98     -5.938250  2335.01  2343.89
# 77763 2017-06-28 00:01:00  2499.39   2682.25     -6.817411  2495.00  2499.33
# 77764 2017-06-28 00:02:00  2337.18   2491.98     -6.211928  2337.18  2340.00
# 77765 2017-06-28 00:02:00  2492.76   2682.25     -7.064591  2492.76  2495.00
# 77766 2017-06-28 00:03:00  2335.02   2491.98     -6.298606  2335.01  2335.02
#
#           low     high        volume
# 77762  2307.0  2473.19  20719.583592
# 77763  2444.0  2780.62   2265.557866
# 77764  2307.0  2473.19  20732.082581
# 77765  2444.0  2780.62   2262.618866
# 77766  2307.0  2473.19  20665.357191

# %%
df = df[['last']]
dataset = df.values
dataset = dataset.astype('float32')
dataset
# Out:
# array([[2344.  ],
#        [2499.39],
#        [2337.18],
#        ...,
#        [2394.03],
#        [2320.47],
#        [2394.03]], dtype=float32)

# %%
scaler = MinMaxScaler(feature_range=(0, 1))
dataset = scaler.fit_transform(dataset)
dataset
# Out:
# array([[0.1997695 ],
#        [0.49828053],
#        [0.18666792],
#        ...,
#        [0.29587936],
#        [0.15456724],
#        [0.29587936]], dtype=float32)

# %%
train_size = int(len(dataset) * 0.67)
test_size = len(dataset) - train_size
train, test = dataset[0:train_size, :], dataset[train_size:len(dataset), :]
print(len(train), len(test))
# Out:
# 31942 15734

# %%
def create_dataset(dataset, look_back=1):
  dataX, dataY = [], []
  for i in range(len(dataset)-look_back-1):
    a = dataset[i:(i+look_back), 0]
    dataX.append(a)
    dataY.append(dataset[i + look_back, 0])
  return np.array(dataX), np.array(dataY)

# %%
look_back = 10
trainX, trainY = create_dataset(train, look_back=look_back)
testX, testY = create_dataset(test, look_back=look_back)

# %%
trainX
# Out:
# array([[0.1997695 , 0.49828053, 0.18666792, ..., 0.4975314 , 0.19973087,
#         0.4860053 ],
#        [0.49828053, 0.18666792, 0.4855442 , ..., 0.19973087, 0.4860053 ,
#         0.18442059],
#        [0.18666792, 0.4855442 , 0.18251848, ..., 0.4860053 , 0.18442059,
#         0.48598576],
#        ...,
#        [0.53376245, 0.6943617 , 0.53105354, ..., 0.7082124 , 0.5205841 ,
#         0.7081547 ],
#        [0.6943617 , 0.53105354, 0.70823145, ..., 0.5205841 , 0.7081547 ,
#         0.52665424],
#        [0.53105354, 0.70823145, 0.5332055 , ..., 0.7081547 , 0.52665424,
#         0.7081547 ]], dtype=float32)

# %%
trainX = np.reshape(trainX, (trainX.shape[0], 1, trainX.shape[1]))
testX = np.reshape(testX, (testX.shape[0], 1, testX.shape[1]))

# %%
model = Sequential()
model.add(LSTM(4, input_shape=(1, look_back)))
model.add(Dense(1))
model.compile(loss='mean_squared_error', optimizer='adam')
model.fit(trainX, trainY, epochs=100, batch_size=256, verbose=2)
# Out:
# Epoch 1/100
# 125/125 - 2s - loss: 0.4180 - 2s/epoch - 17ms/step
# Epoch 2/100
# 125/125 - 0s - loss: 0.0440 - 274ms/epoch - 2ms/step
# Epoch 3/100
# 125/125 - 0s - loss: 0.0113 - 259ms/epoch - 2ms/step
# Epoch 4/100
# 125/125 - 0s - loss: 0.0097 - 244ms/epoch - 2ms/step
# Epoch 5/100
# 125/125 - 0s - loss: 0.0081 - 260ms/epoch - 2ms/step
# Epoch 6/100
# 125/125 - 0s - loss: 0.0064 - 272ms/epoch - 2ms/step
# Epoch 7/100
# 125/125 - 0s - loss: 0.0048 - 352ms/epoch - 3ms/step
# Epoch 8/100
# 125/125 - 0s - loss: 0.0033 - 280ms/epoch - 2ms/step
# Epoch 9/100
# 125/125 - 0s - loss: 0.0021 - 285ms/epoch - 2ms/step
# Epoch 10/100
# 125/125 - 0s - loss: 0.0012 - 236ms/epoch - 2ms/step
# Epoch 11/100
# 125/125 - 0s - loss: 7.3725e-04 - 230ms/epoch - 2ms/step
# Epoch 12/100
# 125/125 - 0s - loss: 5.0265e-04 - 298ms/epoch - 2ms/step
# Epoch 13/100
# 125/125 - 0s - loss: 3.8113e-04 - 280ms/epoch - 2ms/step
# Epoch 14/100
# 125/125 - 0s - loss: 3.0383e-04 - 273ms/epoch - 2ms/step
# Epoch 15/100
# 125/125 - 0s - loss: 2.4767e-04 - 242ms/epoch - 2ms/step
# Epoch 16/100
# 125/125 - 0s - loss: 2.0559e-04 - 252ms/epoch - 2ms/step
# Epoch 17/100
# 125/125 - 0s - loss: 1.7438e-04 - 262ms/epoch - 2ms/step
# Epoch 18/100
# 125/125 - 0s - loss: 1.5212e-04 - 248ms/epoch - 2ms/step
# Epoch 19/100
# 125/125 - 0s - loss: 1.3658e-04 - 234ms/epoch - 2ms/step
# Epoch 20/100
# 125/125 - 0s - loss: 1.2626e-04 - 248ms/epoch - 2ms/step
# Epoch 21/100
# 125/125 - 0s - loss: 1.1962e-04 - 281ms/epoch - 2ms/step
# Epoch 22/100
# 125/125 - 0s - loss: 1.1546e-04 - 250ms/epoch - 2ms/step
# Epoch 23/100
# 125/125 - 0s - loss: 1.1298e-04 - 267ms/epoch - 2ms/step
# Epoch 24/100
# 125/125 - 0s - loss: 1.1136e-04 - 289ms/epoch - 2ms/step
# Epoch 25/100
# 125/125 - 0s - loss: 1.1038e-04 - 211ms/epoch - 2ms/step
# Epoch 26/100
# 125/125 - 0s - loss: 1.0969e-04 - 249ms/epoch - 2ms/step
# Epoch 27/100
# 125/125 - 0s - loss: 1.0908e-04 - 250ms/epoch - 2ms/step
# Epoch 28/100
# 125/125 - 0s - loss: 1.0877e-04 - 210ms/epoch - 2ms/step
# Epoch 29/100
# 125/125 - 0s - loss: 1.0837e-04 - 223ms/epoch - 2ms/step
# Epoch 30/100
# 125/125 - 0s - loss: 1.0791e-04 - 256ms/epoch - 2ms/step
# Epoch 31/100
# 125/125 - 0s - loss: 1.0744e-04 - 281ms/epoch - 2ms/step
# Epoch 32/100
# 125/125 - 0s - loss: 1.0704e-04 - 316ms/epoch - 3ms/step
# Epoch 33/100
# 125/125 - 0s - loss: 1.0662e-04 - 261ms/epoch - 2ms/step
# Epoch 34/100
# 125/125 - 0s - loss: 1.0624e-04 - 367ms/epoch - 3ms/step
# Epoch 35/100
# 125/125 - 0s - loss: 1.0588e-04 - 399ms/epoch - 3ms/step
# Epoch 36/100
# 125/125 - 0s - loss: 1.0557e-04 - 400ms/epoch - 3ms/step
# Epoch 37/100
# 125/125 - 0s - loss: 1.0519e-04 - 337ms/epoch - 3ms/step
# Epoch 38/100
# 125/125 - 0s - loss: 1.0476e-04 - 280ms/epoch - 2ms/step
# Epoch 39/100
# 125/125 - 0s - loss: 1.0459e-04 - 202ms/epoch - 2ms/step
# Epoch 40/100
# 125/125 - 0s - loss: 1.0422e-04 - 201ms/epoch - 2ms/step
# Epoch 41/100
# 125/125 - 0s - loss: 1.0424e-04 - 213ms/epoch - 2ms/step
# Epoch 42/100
# 125/125 - 0s - loss: 1.0361e-04 - 226ms/epoch - 2ms/step
# Epoch 43/100
# 125/125 - 0s - loss: 1.0336e-04 - 221ms/epoch - 2ms/step
# Epoch 44/100
# 125/125 - 0s - loss: 1.0314e-04 - 222ms/epoch - 2ms/step
# Epoch 45/100
# 125/125 - 0s - loss: 1.0270e-04 - 215ms/epoch - 2ms/step
# Epoch 46/100
# 125/125 - 0s - loss: 1.0268e-04 - 233ms/epoch - 2ms/step
# Epoch 47/100
# 125/125 - 0s - loss: 1.0261e-04 - 215ms/epoch - 2ms/step
# Epoch 48/100
# 125/125 - 0s - loss: 1.0211e-04 - 220ms/epoch - 2ms/step
# Epoch 49/100
# 125/125 - 0s - loss: 1.0199e-04 - 245ms/epoch - 2ms/step
# Epoch 50/100
# 125/125 - 0s - loss: 1.0188e-04 - 243ms/epoch - 2ms/step
# Epoch 51/100
# 125/125 - 0s - loss: 1.0123e-04 - 256ms/epoch - 2ms/step
# Epoch 52/100
# 125/125 - 0s - loss: 1.0118e-04 - 265ms/epoch - 2ms/step
# Epoch 53/100
# 125/125 - 0s - loss: 1.0086e-04 - 261ms/epoch - 2ms/step
# Epoch 54/100
# 125/125 - 0s - loss: 1.0037e-04 - 225ms/epoch - 2ms/step
# Epoch 55/100
# 125/125 - 0s - loss: 1.0016e-04 - 247ms/epoch - 2ms/step
# Epoch 56/100
# 125/125 - 0s - loss: 9.9849e-05 - 248ms/epoch - 2ms/step
# Epoch 57/100
# 125/125 - 0s - loss: 1.0025e-04 - 253ms/epoch - 2ms/step
# Epoch 58/100
# 125/125 - 0s - loss: 9.9240e-05 - 231ms/epoch - 2ms/step
# Epoch 59/100
# 125/125 - 0s - loss: 9.9091e-05 - 240ms/epoch - 2ms/step
# Epoch 60/100
# 125/125 - 0s - loss: 9.8558e-05 - 247ms/epoch - 2ms/step
# Epoch 61/100
# 125/125 - 0s - loss: 9.8188e-05 - 212ms/epoch - 2ms/step
# Epoch 62/100
# 125/125 - 0s - loss: 9.8382e-05 - 223ms/epoch - 2ms/step
# Epoch 63/100
# 125/125 - 0s - loss: 9.7598e-05 - 265ms/epoch - 2ms/step
# Epoch 64/100
# 125/125 - 0s - loss: 9.8755e-05 - 216ms/epoch - 2ms/step
# Epoch 65/100
# 125/125 - 0s - loss: 9.7243e-05 - 241ms/epoch - 2ms/step
# Epoch 66/100
# 125/125 - 0s - loss: 9.7024e-05 - 245ms/epoch - 2ms/step
# Epoch 67/100
# 125/125 - 0s - loss: 9.6333e-05 - 302ms/epoch - 2ms/step
# Epoch 68/100
# 125/125 - 0s - loss: 9.6415e-05 - 293ms/epoch - 2ms/step
# Epoch 69/100
# 125/125 - 0s - loss: 9.5521e-05 - 246ms/epoch - 2ms/step
# Epoch 70/100
# 125/125 - 0s - loss: 9.6246e-05 - 208ms/epoch - 2ms/step
# Epoch 71/100
# 125/125 - 0s - loss: 9.4766e-05 - 234ms/epoch - 2ms/step
# Epoch 72/100
# 125/125 - 0s - loss: 9.4842e-05 - 295ms/epoch - 2ms/step
# Epoch 73/100
# 125/125 - 0s - loss: 9.5705e-05 - 316ms/epoch - 3ms/step
# Epoch 74/100
# 125/125 - 0s - loss: 9.3882e-05 - 240ms/epoch - 2ms/step
# Epoch 75/100
# 125/125 - 0s - loss: 9.4415e-05 - 259ms/epoch - 2ms/step
# Epoch 76/100
# 125/125 - 0s - loss: 9.3197e-05 - 265ms/epoch - 2ms/step
# Epoch 77/100
# 125/125 - 0s - loss: 9.2436e-05 - 273ms/epoch - 2ms/step
# Epoch 78/100
# 125/125 - 0s - loss: 9.2741e-05 - 264ms/epoch - 2ms/step
# Epoch 79/100
# 125/125 - 0s - loss: 9.2819e-05 - 341ms/epoch - 3ms/step
# Epoch 80/100
# 125/125 - 0s - loss: 9.2548e-05 - 326ms/epoch - 3ms/step
# Epoch 81/100
# 125/125 - 0s - loss: 9.1341e-05 - 325ms/epoch - 3ms/step
# Epoch 82/100
# 125/125 - 0s - loss: 9.2713e-05 - 313ms/epoch - 3ms/step
# Epoch 83/100
# 125/125 - 0s - loss: 9.1052e-05 - 321ms/epoch - 3ms/step
# Epoch 84/100
# 125/125 - 0s - loss: 9.0742e-05 - 273ms/epoch - 2ms/step
# Epoch 85/100
# 125/125 - 0s - loss: 9.0111e-05 - 245ms/epoch - 2ms/step
# Epoch 86/100
# 125/125 - 0s - loss: 9.1637e-05 - 242ms/epoch - 2ms/step
# Epoch 87/100
# 125/125 - 0s - loss: 9.0109e-05 - 302ms/epoch - 2ms/step
# Epoch 88/100
# 125/125 - 0s - loss: 8.9121e-05 - 300ms/epoch - 2ms/step
# Epoch 89/100
# 125/125 - 0s - loss: 8.9165e-05 - 219ms/epoch - 2ms/step
# Epoch 90/100
# 125/125 - 0s - loss: 8.8456e-05 - 253ms/epoch - 2ms/step
# Epoch 91/100
# 125/125 - 0s - loss: 8.8383e-05 - 266ms/epoch - 2ms/step
# Epoch 92/100
# 125/125 - 0s - loss: 8.7486e-05 - 223ms/epoch - 2ms/step
# Epoch 93/100
# 125/125 - 0s - loss: 8.7593e-05 - 257ms/epoch - 2ms/step
# Epoch 94/100
# 125/125 - 0s - loss: 8.7099e-05 - 245ms/epoch - 2ms/step
# Epoch 95/100
# 125/125 - 0s - loss: 8.7148e-05 - 235ms/epoch - 2ms/step
# Epoch 96/100
# 125/125 - 0s - loss: 8.7265e-05 - 215ms/epoch - 2ms/step
# Epoch 97/100
# 125/125 - 0s - loss: 8.6741e-05 - 235ms/epoch - 2ms/step
# Epoch 98/100
# 125/125 - 0s - loss: 8.7120e-05 - 265ms/epoch - 2ms/step
# Epoch 99/100
# 125/125 - 0s - loss: 8.5976e-05 - 253ms/epoch - 2ms/step
# Epoch 100/100
# 125/125 - 0s - loss: 8.6475e-05 - 230ms/epoch - 2ms/step

# %%
trainPredict = model.predict(trainX)
testPredict = model.predict(testX)
# Out:
# 998/998 [==============================] - 2s 1ms/step
# 492/492 [==============================] - 1s 1ms/step

# %%
trainPredict = scaler.inverse_transform(trainPredict)
trainY = scaler.inverse_transform([trainY])
testPredict = scaler.inverse_transform(testPredict)
testY = scaler.inverse_transform([testY])

# %%
trainScore = math.sqrt(mean_squared_error(trainY[0], trainPredict[:, 0]))
print('Train Score: %.2f RMSE' % (trainScore))
testScore = math.sqrt(mean_squared_error(testY[0], testPredict[:, 0]))
print('Test Score: %.2f RMSE' % (testScore))
# Out:
# Train Score: 4.79 RMSE
# Test Score: 6.60 RMSE

# %%
trainPredictPlot = np.empty_like(dataset)
trainPredictPlot[:, :] = np.nan
trainPredictPlot[look_back:len(trainPredict) + look_back, :] = trainPredict

# %%
testPredictPlot = np.empty_like(dataset)
testPredictPlot[:, :] = np.nan
testPredictPlot[len(trainPredict) + (look_back * 2) + 1:len(dataset) - 1, :] = testPredict

# %%
plt.plot(df['last'], label='Actual')
plt.plot(pd.DataFrame(trainPredictPlot, columns=["close"], index=df.index).close, label='Training')
plt.plot(pd.DataFrame(testPredictPlot, columns=["close"], index=df.index).close, label='Testing')
plt.legend(loc='best')
plt.show()
