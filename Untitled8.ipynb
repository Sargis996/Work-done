# %%
import pandas as pd

df = pd.read_csv("/Employees (1).csv")

# %%
df.isna().sum()
# Out:
# Gender        0
# Experience    0
# Salary        0
# dtype: int64

# %%
from sklearn.model_selection import train_test_split

X = df[['Gender', 'Experience']]
y = df['Salary']

X_train, X_test, y_train, y_test = train_test_split(X, y, test_size=0.3, random_state=42)

# %%
import seaborn as sns

sns.histplot(df, x='Salary', hue='Gender', bins=30)
# Out:
# <Axes: xlabel='Salary', ylabel='Count'>

# %%
sns.scatterplot(data=df, x="Experience", y="Salary", hue="Gender")
# Out:
# <Axes: xlabel='Experience', ylabel='Salary'>

# %%
sns.scatterplot(data=df, x="Gender", y="Salary", hue="Experience")
# Out:
# <Axes: xlabel='Gender', ylabel='Salary'>

# %%
from sklearn.linear_model import LinearRegression

model = LinearRegression()

X_train_female = X_train[X_train['Gender'] == 'Female'].drop('Gender', axis=1)
X_train_male = X_train[X_train['Gender'] == 'Male'].drop('Gender', axis=1)

y_train_female = y_train[X_train['Gender'] == 'Female']
y_train_male = y_train[X_train['Gender'] == 'Male']

model_female = model.fit(X_train_female, y_train_female)
model_male = model.fit(X_train_male, y_train_male)

# %%
import numpy as np

y_train_female_log = np.log(y_train_female)
y
